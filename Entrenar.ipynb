# %% [markdown]
# ### Librerías y API tensorflow object detection

# %%
# %cd
  
# !git clone --quiet https://github.com/tensorflow/models.git

# !apt-get install -qq protobuf-compiler python-tk

# !pip install -q Cython contextlib2 pillow lxml matplotlib PyDrive

# !pip install -q pycocotools

# %cd ~/models/research
# !protoc object_detection/protos/*.proto --python_out=.
# Out:
# /root
# /root/models/research

# %%
# %cd ~/models/research/object_detection
# Out:
# /root/models/research/object_detection

# %%
# %ls
# Out:
# anchor_generators/                   legacy/
# box_coders/                          matchers/
# builders/                            meta_architectures/
# CONTRIBUTING.md                      metrics/
# core/                                model_hparams.py
# data/                                model_lib.py
# data_decoders/                       model_lib_test.py
# dataset_tools/                       model_lib_v2.py
# dockerfiles/                         model_lib_v2_test.py
# eval_util.py                         model_main.py
# eval_util_test.py                    models/
# exporter.py                          model_tpu_main.py
# exporter_test.py                     object_detection_tutorial.ipynb
# export_inference_graph.py            predictors/
# export_tflite_ssd_graph_lib.py       protos/
# export_tflite_ssd_graph_lib_test.py  README.md
# export_tflite_ssd_graph.py           samples/
# g3doc/                               test_ckpt/
# ...

# %% [markdown]
# ### Configuración del path environment

# %%
import os
os.environ['PYTHONPATH'] += ':/root/models/research/:/root/models/research/slim/'

# %%
# !python ~/models/research/object_detection/builders/model_builder_test.py
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /root/models/research/slim/nets/inception_resnet_v2.py:373: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /root/models/research/slim/nets/mobilenet/mobilenet.py:397: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# Running tests under Python 3.6.8: /usr/bin/python3
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_model_from_config_with_example_miner
# [       OK ] ModelBuilderTest.test_create_faster_rcnn_model_from_config_with_example_miner
# ...

# %% [markdown]
# ### Montar drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /root/models/research/object_detection
# Out:
# /root/models/research/object_detection

# %%
# %cd /content/drive/My Drive/TrabajoTerminal/Prueba
# Out:
# /content/drive/My Drive/TrabajoTerminal/Prueba

# %%
# %cd /content/drive/My Drive/
# Out:
# [Errno 2] No such file or directory: '/content/drive/My Drive/'
# /content

# %%
# %cd /content/drive/My Drive/
# Out:
# /content/drive/My Drive

# %%
# %cd /content/drive/My Drive/TrabajoTerminal/Prueba
# Out:
# /content/drive/My Drive/TrabajoTerminal/Prueba

# %%
# %ls
# Out:
# 1/                                      pretrained_model/
# 2/                                      recordsantiguos/
# csv_a_tf.py                             setup.py
# Entrenar.ipynb                          test.record
# export_inference_graph.py               training/
# faster_rcnn_resnet101_coco_2018_01_28/  training.record
# label_map.pbtxt                         train.py
# output_inference_graph/                 Validación.ipynb

# %% [markdown]
# # Empezar el entrenamiento

# %%
# !python train.py --logtostderr --train_dir=training --pipeline_config_path=training/ssd_coco.config
# Out:
# INFO:tensorflow:global step 59376: loss = 1.1506 (1.596 sec/step)
# I0925 13:03:08.637715 139739490912128 learning.py:507] global step 59376: loss = 1.1506 (1.596 sec/step)
# INFO:tensorflow:global step 59376: loss = 1.1506 (1.596 sec/step)
# I0925 13:03:08.637715 139739490912128 learning.py:507] global step 59376: loss = 1.1506 (1.596 sec/step)
# INFO:tensorflow:global step 59377: loss = 1.0386 (1.473 sec/step)
# I0925 13:03:10.114207 139739490912128 learning.py:507] global step 59377: loss = 1.0386 (1.473 sec/step)
# INFO:tensorflow:global step 59377: loss = 1.0386 (1.473 sec/step)
# I0925 13:03:10.114207 139739490912128 learning.py:507] global step 59377: loss = 1.0386 (1.473 sec/step)
# INFO:tensorflow:global step 59378: loss = 0.9770 (1.231 sec/step)
# I0925 13:03:11.347613 139739490912128 learning.py:507] global step 59378: loss = 0.9770 (1.231 sec/step)
# INFO:tensorflow:global step 59378: loss = 0.9770 (1.231 sec/step)
# ...

# %% [markdown]
# ### Exportar el modelo

# %%
# !python export_inference_graph.py --input_type image_tensor --pipeline_config_path=training/ssd_coco.config --trained_checkpoint_prefix training2/model.ckpt-50000 --output_directory=output_inference_graph
# Out:
# WARNING:tensorflow:From /root/models/research/slim/nets/inception_resnet_v2.py:373: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /root/models/research/slim/nets/mobilenet/mobilenet.py:397: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From export_inference_graph.py:150: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From export_inference_graph.py:133: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W0925 16:20:04.460433 140503455295360 deprecation_wrapper.py:119] From export_inference_graph.py:133: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# WARNING:tensorflow:From /root/models/research/object_detection/exporter.py:381: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
#
# ...
